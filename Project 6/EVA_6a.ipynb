# %% [markdown]
# ### Import Libraries

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Read DataSet

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step

# %% [markdown]
# ### Classes

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# ### Functions for Post Training Analysis

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %% [markdown]
# ### Preparing Data

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# ### Existing Code

# %% [markdown]
# #### Model Architecture

# %%
# Define the model
model = Sequential()
model.add(Convolution2D(48, 3, 3, border_mode='same', input_shape=(32, 32, 3)))
model.add(Activation('relu'))
model.add(Convolution2D(48, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(96, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(96, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(192, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(192, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3))`
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3))`
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3))`
#   app.launch_new_instance()

# %% [markdown]
# ####  Model Summary

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_109 (Conv2D)          (None, 32, 32, 48)        1344
# _________________________________________________________________
# activation_82 (Activation)   (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_110 (Conv2D)          (None, 30, 30, 48)        20784
# _________________________________________________________________
# activation_83 (Activation)   (None, 30, 30, 48)        0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 15, 15, 48)        0
# _________________________________________________________________
# dropout_73 (Dropout)         (None, 15, 15, 48)        0
# _________________________________________________________________
# conv2d_111 (Conv2D)          (None, 15, 15, 96)        41568
# _________________________________________________________________
# activation_84 (Activation)   (None, 15, 15, 96)        0
# _________________________________________________________________
# conv2d_112 (Conv2D)          (None, 13, 13, 96)        83040
# _________________________________________________________________
# activation_85 (Activation)   (None, 13, 13, 96)        0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 6, 6, 96)          0
# _________________________________________________________________
# dropout_74 (Dropout)         (None, 6, 6, 96)          0
# _________________________________________________________________
# conv2d_113 (Conv2D)          (None, 6, 6, 192)         166080
# _________________________________________________________________
# activation_86 (Activation)   (None, 6, 6, 192)         0
# _________________________________________________________________
# conv2d_114 (Conv2D)          (None, 4, 4, 192)         331968
# _________________________________________________________________
# activation_87 (Activation)   (None, 4, 4, 192)         0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 2, 2, 192)         0
# _________________________________________________________________
# dropout_75 (Dropout)         (None, 2, 2, 192)         0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 768)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               393728
# _________________________________________________________________
# activation_88 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_76 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_89 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_77 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,172,410
# Trainable params: 1,172,410
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train Model

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=100)`
#   if sys.path[0] == '':
# Epoch 1/100
# 390/390 [==============================] - 13s 33ms/step - loss: 1.8555 - acc: 0.2920 - val_loss: 1.4751 - val_acc: 0.4639
# Epoch 2/100
# 390/390 [==============================] - 9s 23ms/step - loss: 1.3477 - acc: 0.5125 - val_loss: 1.1195 - val_acc: 0.5991
# Epoch 3/100
# 390/390 [==============================] - 9s 23ms/step - loss: 1.1211 - acc: 0.6029 - val_loss: 1.0076 - val_acc: 0.6420
# Epoch 4/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.9935 - acc: 0.6527 - val_loss: 0.9109 - val_acc: 0.6888
# Epoch 5/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.8896 - acc: 0.6926 - val_loss: 0.7727 - val_acc: 0.7353
# Epoch 6/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.8101 - acc: 0.7233 - val_loss: 0.7909 - val_acc: 0.7319
# Epoch 7/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.7538 - acc: 0.7414 - val_loss: 0.7088 - val_acc: 0.7576
# Epoch 8/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.7072 - acc: 0.7577 - val_loss: 0.6790 - val_acc: 0.7717
# Epoch 9/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.6702 - acc: 0.7740 - val_loss: 0.6574 - val_acc: 0.7799
# Epoch 10/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.6365 - acc: 0.7826 - val_loss: 0.6378 - val_acc: 0.7859
# Epoch 11/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.6086 - acc: 0.7913 - val_loss: 0.6293 - val_acc: 0.7921
# Epoch 12/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5873 - acc: 0.7997 - val_loss: 0.6473 - val_acc: 0.7841
# Epoch 13/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5766 - acc: 0.8030 - val_loss: 0.5969 - val_acc: 0.8029
# Epoch 14/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5453 - acc: 0.8128 - val_loss: 0.6196 - val_acc: 0.7955
# Epoch 15/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5331 - acc: 0.8176 - val_loss: 0.6378 - val_acc: 0.7929
# Epoch 16/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5104 - acc: 0.8263 - val_loss: 0.5694 - val_acc: 0.8162
# Epoch 17/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4965 - acc: 0.8327 - val_loss: 0.5724 - val_acc: 0.8101
# Epoch 18/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4914 - acc: 0.8313 - val_loss: 0.5843 - val_acc: 0.8068
# Epoch 19/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4785 - acc: 0.8356 - val_loss: 0.5906 - val_acc: 0.8094
# Epoch 20/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4678 - acc: 0.8401 - val_loss: 0.5923 - val_acc: 0.8084
# Epoch 21/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4525 - acc: 0.8461 - val_loss: 0.5947 - val_acc: 0.8094
# Epoch 22/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4510 - acc: 0.8469 - val_loss: 0.5815 - val_acc: 0.8124
# Epoch 23/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4438 - acc: 0.8475 - val_loss: 0.5927 - val_acc: 0.8112
# Epoch 24/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4333 - acc: 0.8505 - val_loss: 0.6036 - val_acc: 0.8082
# Epoch 25/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4222 - acc: 0.8551 - val_loss: 0.6014 - val_acc: 0.8044
# Epoch 26/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4223 - acc: 0.8569 - val_loss: 0.5824 - val_acc: 0.8196
# Epoch 27/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4055 - acc: 0.8634 - val_loss: 0.6107 - val_acc: 0.8141
# Epoch 28/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4093 - acc: 0.8618 - val_loss: 0.5963 - val_acc: 0.8143
# Epoch 29/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3943 - acc: 0.8656 - val_loss: 0.5745 - val_acc: 0.8221
# Epoch 30/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3900 - acc: 0.8676 - val_loss: 0.5620 - val_acc: 0.8194
# Epoch 31/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3780 - acc: 0.8723 - val_loss: 0.5799 - val_acc: 0.8240
# Epoch 32/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3796 - acc: 0.8713 - val_loss: 0.5751 - val_acc: 0.8187
# Epoch 33/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3718 - acc: 0.8748 - val_loss: 0.5772 - val_acc: 0.8256
# Epoch 34/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3628 - acc: 0.8752 - val_loss: 0.6127 - val_acc: 0.8124
# Epoch 35/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3618 - acc: 0.8801 - val_loss: 0.5875 - val_acc: 0.8213
# Epoch 36/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3600 - acc: 0.8788 - val_loss: 0.5764 - val_acc: 0.8192
# Epoch 37/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3585 - acc: 0.8789 - val_loss: 0.6173 - val_acc: 0.8199
# Epoch 38/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3543 - acc: 0.8803 - val_loss: 0.5742 - val_acc: 0.8199
# Epoch 39/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3471 - acc: 0.8835 - val_loss: 0.6030 - val_acc: 0.8167
# Epoch 40/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3473 - acc: 0.8833 - val_loss: 0.6019 - val_acc: 0.8169
# Epoch 41/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3349 - acc: 0.8877 - val_loss: 0.6067 - val_acc: 0.8217
# Epoch 42/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3414 - acc: 0.8868 - val_loss: 0.5837 - val_acc: 0.8289
# Epoch 43/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3239 - acc: 0.8918 - val_loss: 0.5971 - val_acc: 0.8248
# Epoch 44/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3345 - acc: 0.8879 - val_loss: 0.5913 - val_acc: 0.8216
# Epoch 45/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3272 - acc: 0.8898 - val_loss: 0.6006 - val_acc: 0.8173
# Epoch 46/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3285 - acc: 0.8906 - val_loss: 0.6042 - val_acc: 0.8224
# Epoch 47/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3186 - acc: 0.8937 - val_loss: 0.5839 - val_acc: 0.8248
# Epoch 48/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3276 - acc: 0.8908 - val_loss: 0.6611 - val_acc: 0.8112
# Epoch 49/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3215 - acc: 0.8948 - val_loss: 0.6294 - val_acc: 0.8192
# Epoch 50/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3052 - acc: 0.8990 - val_loss: 0.5913 - val_acc: 0.8255
# Epoch 51/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3065 - acc: 0.8982 - val_loss: 0.5808 - val_acc: 0.8288
# Epoch 52/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2967 - acc: 0.9002 - val_loss: 0.6393 - val_acc: 0.8187
# Epoch 53/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2954 - acc: 0.9010 - val_loss: 0.6438 - val_acc: 0.8172
# Epoch 54/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3034 - acc: 0.9004 - val_loss: 0.6186 - val_acc: 0.8258
# Epoch 55/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2966 - acc: 0.9011 - val_loss: 0.5959 - val_acc: 0.8283
# Epoch 56/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2967 - acc: 0.9031 - val_loss: 0.5941 - val_acc: 0.8257
# Epoch 57/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3043 - acc: 0.9001 - val_loss: 0.5869 - val_acc: 0.8242
# Epoch 58/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3067 - acc: 0.8998 - val_loss: 0.5882 - val_acc: 0.8281
# Epoch 59/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2879 - acc: 0.9053 - val_loss: 0.6076 - val_acc: 0.8212
# Epoch 60/100
# 390/390 [==============================] - 10s 25ms/step - loss: 0.2933 - acc: 0.9029 - val_loss: 0.6129 - val_acc: 0.8266
# Epoch 61/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2882 - acc: 0.9059 - val_loss: 0.6116 - val_acc: 0.8275
# Epoch 62/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2886 - acc: 0.9070 - val_loss: 0.5957 - val_acc: 0.8285
# Epoch 63/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2870 - acc: 0.9048 - val_loss: 0.5955 - val_acc: 0.8292
# Epoch 64/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2862 - acc: 0.9068 - val_loss: 0.5922 - val_acc: 0.8304
# Epoch 65/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2755 - acc: 0.9104 - val_loss: 0.5909 - val_acc: 0.8324
# Epoch 66/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2813 - acc: 0.9077 - val_loss: 0.6104 - val_acc: 0.8277
# Epoch 67/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2829 - acc: 0.9073 - val_loss: 0.6415 - val_acc: 0.8236
# Epoch 68/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2727 - acc: 0.9116 - val_loss: 0.6216 - val_acc: 0.8253
# Epoch 69/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2788 - acc: 0.9103 - val_loss: 0.6530 - val_acc: 0.8239
# Epoch 70/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2800 - acc: 0.9090 - val_loss: 0.6271 - val_acc: 0.8290
# Epoch 71/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2744 - acc: 0.9117 - val_loss: 0.6107 - val_acc: 0.8356
# Epoch 72/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2806 - acc: 0.9097 - val_loss: 0.6121 - val_acc: 0.8268
# Epoch 73/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2657 - acc: 0.9144 - val_loss: 0.6046 - val_acc: 0.8302
# Epoch 74/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2724 - acc: 0.9117 - val_loss: 0.6305 - val_acc: 0.8282
# Epoch 75/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2665 - acc: 0.9140 - val_loss: 0.6174 - val_acc: 0.8290
# Epoch 76/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2676 - acc: 0.9149 - val_loss: 0.6425 - val_acc: 0.8283
# Epoch 77/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2742 - acc: 0.9123 - val_loss: 0.6330 - val_acc: 0.8251
# Epoch 78/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2728 - acc: 0.9121 - val_loss: 0.6343 - val_acc: 0.8267
# Epoch 79/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2639 - acc: 0.9153 - val_loss: 0.6132 - val_acc: 0.8290
# Epoch 80/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2731 - acc: 0.9129 - val_loss: 0.6489 - val_acc: 0.8284
# Epoch 81/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2640 - acc: 0.9157 - val_loss: 0.6346 - val_acc: 0.8318
# Epoch 82/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2708 - acc: 0.9145 - val_loss: 0.6402 - val_acc: 0.8240
# Epoch 83/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2644 - acc: 0.9153 - val_loss: 0.6596 - val_acc: 0.8206
# Epoch 84/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2534 - acc: 0.9196 - val_loss: 0.6434 - val_acc: 0.8257
# Epoch 85/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2596 - acc: 0.9184 - val_loss: 0.6457 - val_acc: 0.8256
# Epoch 86/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2626 - acc: 0.9175 - val_loss: 0.6486 - val_acc: 0.8217
# Epoch 87/100
# 390/390 [==============================] - 9s 24ms/step - loss: 0.2602 - acc: 0.9182 - val_loss: 0.6223 - val_acc: 0.8310
# Epoch 88/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2620 - acc: 0.9168 - val_loss: 0.6164 - val_acc: 0.8270
# Epoch 89/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2532 - acc: 0.9197 - val_loss: 0.6444 - val_acc: 0.8260
# Epoch 90/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2546 - acc: 0.9219 - val_loss: 0.6585 - val_acc: 0.8261
# Epoch 91/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2636 - acc: 0.9170 - val_loss: 0.6125 - val_acc: 0.8288
# Epoch 92/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2583 - acc: 0.9181 - val_loss: 0.6079 - val_acc: 0.8328
# Epoch 93/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2590 - acc: 0.9189 - val_loss: 0.6453 - val_acc: 0.8285
# Epoch 94/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2526 - acc: 0.9191 - val_loss: 0.6310 - val_acc: 0.8274
# Epoch 95/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2533 - acc: 0.9213 - val_loss: 0.6325 - val_acc: 0.8293
# Epoch 96/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2473 - acc: 0.9212 - val_loss: 0.6286 - val_acc: 0.8293
# Epoch 97/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2522 - acc: 0.9213 - val_loss: 0.6540 - val_acc: 0.8295
# Epoch 98/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2487 - acc: 0.9228 - val_loss: 0.6279 - val_acc: 0.8353
# Epoch 99/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2498 - acc: 0.9221 - val_loss: 0.6186 - val_acc: 0.8340
# Epoch 100/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2588 - acc: 0.9184 - val_loss: 0.6500 - val_acc: 0.8245
# Model took 904.13 seconds to train
# Accuracy on test data is: 82.45

# %% [markdown]
# ### Modified Code

# %% [markdown]
# #### Model Architecture

# %%
# Define the model
model = Sequential()

# Convolution Block
model.add(Convolution2D(32, 3, 3, border_mode='same', input_shape=(32, 32, 3))) # Dim 32 RF 3
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

# Convolution Block
model.add(Convolution2D(64, 3, 3)) # Dim 30 RF 5
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

# Convolution Block
model.add(Convolution2D(128, 3, 3)) # Dim 28 RF 7
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

# Transition Block
model.add(Convolution2D(32, 1, 1, activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) # Dim 14 RF 14

# Convolution Block
model.add(Convolution2D(64, 3, 3, border_mode='same')) # Dim 14 RF 12
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

# Convolution Block
model.add(Convolution2D(128, 3, 3)) # Dim 12 RF 14
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

# Convolution Block
model.add(Convolution2D(256, 3, 3)) # Dim 10 RF 16
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

# Partial Transition Block
model.add(Convolution2D(32, 1, 1, activation='relu'))


# Convolution Block
model.add(Convolution2D(64, 3, 3, border_mode='same')) # Dim 10 RF 18
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

# Convolution Block
model.add(Convolution2D(128, 3)) # Dim 8 RF 20
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

# Convolution Block
model.add(Convolution2D(256, 3)) # Dim 6 RF 22
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

# Output Block
model.add(Convolution2D(10, 1, activation='relu')) # Dim 6 RF 22
model.add(Convolution2D(10, 6)) # Dim 1 RF 28
model.add(Flatten())
model.add(Activation('softmax'))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3))`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3))`
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), activation="relu")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), activation="relu")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`

# %% [markdown]
# #### Model summary

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_115 (Conv2D)          (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_73 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_90 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_78 (Dropout)         (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_116 (Conv2D)          (None, 30, 30, 64)        18496
# _________________________________________________________________
# batch_normalization_74 (Batc (None, 30, 30, 64)        256
# _________________________________________________________________
# activation_91 (Activation)   (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_79 (Dropout)         (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_117 (Conv2D)          (None, 28, 28, 128)       73856
# _________________________________________________________________
# batch_normalization_75 (Batc (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_92 (Activation)   (None, 28, 28, 128)       0
# _________________________________________________________________
# dropout_80 (Dropout)         (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_118 (Conv2D)          (None, 28, 28, 32)        4128
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_119 (Conv2D)          (None, 14, 14, 64)        18496
# _________________________________________________________________
# batch_normalization_76 (Batc (None, 14, 14, 64)        256
# _________________________________________________________________
# activation_93 (Activation)   (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_81 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_120 (Conv2D)          (None, 12, 12, 128)       73856
# _________________________________________________________________
# batch_normalization_77 (Batc (None, 12, 12, 128)       512
# _________________________________________________________________
# activation_94 (Activation)   (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_82 (Dropout)         (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_121 (Conv2D)          (None, 10, 10, 256)       295168
# _________________________________________________________________
# batch_normalization_78 (Batc (None, 10, 10, 256)       1024
# _________________________________________________________________
# activation_95 (Activation)   (None, 10, 10, 256)       0
# _________________________________________________________________
# dropout_83 (Dropout)         (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_122 (Conv2D)          (None, 10, 10, 32)        8224
# _________________________________________________________________
# conv2d_123 (Conv2D)          (None, 10, 10, 64)        18496
# _________________________________________________________________
# batch_normalization_79 (Batc (None, 10, 10, 64)        256
# _________________________________________________________________
# activation_96 (Activation)   (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_84 (Dropout)         (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_124 (Conv2D)          (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_80 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_97 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_85 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_125 (Conv2D)          (None, 6, 6, 256)         295168
# _________________________________________________________________
# batch_normalization_81 (Batc (None, 6, 6, 256)         1024
# _________________________________________________________________
# activation_98 (Activation)   (None, 6, 6, 256)         0
# _________________________________________________________________
# dropout_86 (Dropout)         (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_126 (Conv2D)          (None, 6, 6, 10)          2570
# _________________________________________________________________
# conv2d_127 (Conv2D)          (None, 1, 1, 10)          3610
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 10)                0
# _________________________________________________________________
# activation_99 (Activation)   (None, 10)                0
# =================================================================
# Total params: 891,300
# Trainable params: 889,060
# Non-trainable params: 2,240
# _________________________________________________________________

# %% [markdown]
# #### Model Compile and Training

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler, ModelCheckpoint

# Image Normalization
datagen = ImageDataGenerator(zoom_range=0.0,featurewise_center=True, featurewise_std_normalization=True,
                             horizontal_flip=False) 

# LR Scheduler
def scheduler(epoch, lr):
  return round(0.003 * 1/(1 + 0.319 * epoch), 10)

# Compile Model
model.compile(loss='categorical_crossentropy', 
              optimizer=Adam(lr=0.003),
              metrics=['accuracy'])

# Checkpoint to save best model
# !mkdir "Assignment6a"
filepath="Assignment6a//maxAccuracy.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

callbacks_list = [checkpoint, LearningRateScheduler(scheduler, verbose=1)]


start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 256),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1, callbacks=callbacks_list)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# mkdir: cannot create directory ‘Assignment6a’: File exists
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=195, epochs=100)`
# Epoch 1/100
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:716: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:724: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 00001: LearningRateScheduler setting learning rate to 0.003.
# 195/195 [==============================] - 62s 317ms/step - loss: 1.6610 - acc: 0.3763 - val_loss: 2.9310 - val_acc: 0.3533
#
# Epoch 00001: val_acc improved from -inf to 0.35330, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0022744503.
# 195/195 [==============================] - 50s 256ms/step - loss: 1.2101 - acc: 0.5618 - val_loss: 1.5626 - val_acc: 0.4807
#
# Epoch 00002: val_acc improved from 0.35330 to 0.48070, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0018315018.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.9877 - acc: 0.6472 - val_loss: 1.2866 - val_acc: 0.5805
#
# Epoch 00003: val_acc improved from 0.48070 to 0.58050, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0015329586.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.8432 - acc: 0.7006 - val_loss: 1.0980 - val_acc: 0.6401
#
# Epoch 00004: val_acc improved from 0.58050 to 0.64010, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0013181019.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.7328 - acc: 0.7407 - val_loss: 0.9494 - val_acc: 0.6737
#
# Epoch 00005: val_acc improved from 0.64010 to 0.67370, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0011560694.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.6752 - acc: 0.7643 - val_loss: 0.7433 - val_acc: 0.7449
#
# Epoch 00006: val_acc improved from 0.67370 to 0.74490, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0010295127.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.6122 - acc: 0.7861 - val_loss: 0.7342 - val_acc: 0.7523
#
# Epoch 00007: val_acc improved from 0.74490 to 0.75230, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0009279307.
# 195/195 [==============================] - 50s 256ms/step - loss: 0.5746 - acc: 0.7999 - val_loss: 0.6847 - val_acc: 0.7645
#
# Epoch 00008: val_acc improved from 0.75230 to 0.76450, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0008445946.
# 195/195 [==============================] - 50s 256ms/step - loss: 0.5361 - acc: 0.8122 - val_loss: 0.6814 - val_acc: 0.7684
#
# Epoch 00009: val_acc improved from 0.76450 to 0.76840, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0007749935.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.5021 - acc: 0.8246 - val_loss: 0.6599 - val_acc: 0.7822
#
# Epoch 00010: val_acc improved from 0.76840 to 0.78220, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0007159905.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.4743 - acc: 0.8352 - val_loss: 0.5857 - val_acc: 0.8028
#
# Epoch 00011: val_acc improved from 0.78220 to 0.80280, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.000665336.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.4492 - acc: 0.8411 - val_loss: 0.7620 - val_acc: 0.7520
#
# Epoch 00012: val_acc did not improve from 0.80280
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0006213753.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.4270 - acc: 0.8493 - val_loss: 0.6289 - val_acc: 0.7936
#
# Epoch 00013: val_acc did not improve from 0.80280
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0005828638.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.4032 - acc: 0.8576 - val_loss: 0.5856 - val_acc: 0.8122
#
# Epoch 00014: val_acc improved from 0.80280 to 0.81220, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0005488474.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.3873 - acc: 0.8651 - val_loss: 0.6787 - val_acc: 0.7894
#
# Epoch 00015: val_acc did not improve from 0.81220
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0005185825.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.3721 - acc: 0.8696 - val_loss: 0.5838 - val_acc: 0.8138
#
# Epoch 00016: val_acc improved from 0.81220 to 0.81380, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.000491481.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.3556 - acc: 0.8754 - val_loss: 0.5723 - val_acc: 0.8230
#
# Epoch 00017: val_acc improved from 0.81380 to 0.82300, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0004670715.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.3435 - acc: 0.8782 - val_loss: 0.5305 - val_acc: 0.8316
#
# Epoch 00018: val_acc improved from 0.82300 to 0.83160, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0004449718.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.3345 - acc: 0.8830 - val_loss: 0.5634 - val_acc: 0.8269
#
# Epoch 00019: val_acc did not improve from 0.83160
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.000424869.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.3177 - acc: 0.8881 - val_loss: 0.5507 - val_acc: 0.8281
#
# Epoch 00020: val_acc did not improve from 0.83160
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0004065041.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.3096 - acc: 0.8908 - val_loss: 0.5408 - val_acc: 0.8328
#
# Epoch 00021: val_acc improved from 0.83160 to 0.83280, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.000389661.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.2971 - acc: 0.8935 - val_loss: 0.5432 - val_acc: 0.8313
#
# Epoch 00022: val_acc did not improve from 0.83280
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0003741581.
# 195/195 [==============================] - 50s 256ms/step - loss: 0.2923 - acc: 0.8952 - val_loss: 0.5603 - val_acc: 0.8317
#
# Epoch 00023: val_acc did not improve from 0.83280
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0003598417.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.2819 - acc: 0.8982 - val_loss: 0.5251 - val_acc: 0.8439
#
# Epoch 00024: val_acc improved from 0.83280 to 0.84390, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0003465804.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.2729 - acc: 0.9033 - val_loss: 0.5595 - val_acc: 0.8361
#
# Epoch 00025: val_acc did not improve from 0.84390
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0003342618.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.2681 - acc: 0.9056 - val_loss: 0.6111 - val_acc: 0.8246
#
# Epoch 00026: val_acc did not improve from 0.84390
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0003227889.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.2587 - acc: 0.9079 - val_loss: 0.5603 - val_acc: 0.8370
#
# Epoch 00027: val_acc did not improve from 0.84390
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.0003120774.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.2564 - acc: 0.9094 - val_loss: 0.5266 - val_acc: 0.8480
#
# Epoch 00028: val_acc improved from 0.84390 to 0.84800, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.000302054.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.2417 - acc: 0.9130 - val_loss: 0.6150 - val_acc: 0.8272
#
# Epoch 00029: val_acc did not improve from 0.84800
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0002926544.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.2375 - acc: 0.9148 - val_loss: 0.5852 - val_acc: 0.8366
#
# Epoch 00030: val_acc did not improve from 0.84800
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0002838221.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.2340 - acc: 0.9178 - val_loss: 0.5621 - val_acc: 0.8421
#
# Epoch 00031: val_acc did not improve from 0.84800
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0002755074.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.2248 - acc: 0.9198 - val_loss: 0.5327 - val_acc: 0.8501
#
# Epoch 00032: val_acc improved from 0.84800 to 0.85010, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.000267666.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.2188 - acc: 0.9217 - val_loss: 0.5783 - val_acc: 0.8345
#
# Epoch 00033: val_acc did not improve from 0.85010
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0002602585.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.2151 - acc: 0.9227 - val_loss: 0.5770 - val_acc: 0.8447
#
# Epoch 00034: val_acc did not improve from 0.85010
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.00025325.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.2140 - acc: 0.9238 - val_loss: 0.5734 - val_acc: 0.8442
#
# Epoch 00035: val_acc did not improve from 0.85010
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0002466091.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.2055 - acc: 0.9265 - val_loss: 0.5590 - val_acc: 0.8456
#
# Epoch 00036: val_acc did not improve from 0.85010
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0002403076.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.2036 - acc: 0.9280 - val_loss: 0.5541 - val_acc: 0.8491
#
# Epoch 00037: val_acc did not improve from 0.85010
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0002343201.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1957 - acc: 0.9293 - val_loss: 0.5583 - val_acc: 0.8496
#
# Epoch 00038: val_acc did not improve from 0.85010
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0002286237.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1934 - acc: 0.9302 - val_loss: 0.5658 - val_acc: 0.8443
#
# Epoch 00039: val_acc did not improve from 0.85010
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.0002231977.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1910 - acc: 0.9317 - val_loss: 0.5732 - val_acc: 0.8495
#
# Epoch 00040: val_acc did not improve from 0.85010
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.0002180233.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1844 - acc: 0.9332 - val_loss: 0.6142 - val_acc: 0.8364
#
# Epoch 00041: val_acc did not improve from 0.85010
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.0002130833.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1805 - acc: 0.9343 - val_loss: 0.5958 - val_acc: 0.8417
#
# Epoch 00042: val_acc did not improve from 0.85010
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.0002083623.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1814 - acc: 0.9354 - val_loss: 0.6078 - val_acc: 0.8433
#
# Epoch 00043: val_acc did not improve from 0.85010
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.0002038459.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1773 - acc: 0.9362 - val_loss: 0.5849 - val_acc: 0.8461
#
# Epoch 00044: val_acc did not improve from 0.85010
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.0001995211.
# 195/195 [==============================] - 49s 254ms/step - loss: 0.1703 - acc: 0.9381 - val_loss: 0.5697 - val_acc: 0.8489
#
# Epoch 00045: val_acc did not improve from 0.85010
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.0001953761.
# 195/195 [==============================] - 49s 254ms/step - loss: 0.1700 - acc: 0.9391 - val_loss: 0.6042 - val_acc: 0.8446
#
# Epoch 00046: val_acc did not improve from 0.85010
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.0001913998.
# 195/195 [==============================] - 49s 253ms/step - loss: 0.1666 - acc: 0.9401 - val_loss: 0.5508 - val_acc: 0.8541
#
# Epoch 00047: val_acc improved from 0.85010 to 0.85410, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.0001875821.
# 195/195 [==============================] - 49s 253ms/step - loss: 0.1669 - acc: 0.9406 - val_loss: 0.5842 - val_acc: 0.8478
#
# Epoch 00048: val_acc did not improve from 0.85410
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.0001839137.
# 195/195 [==============================] - 49s 253ms/step - loss: 0.1574 - acc: 0.9432 - val_loss: 0.6086 - val_acc: 0.8470
#
# Epoch 00049: val_acc did not improve from 0.85410
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.000180386.
# 195/195 [==============================] - 49s 254ms/step - loss: 0.1558 - acc: 0.9437 - val_loss: 0.6355 - val_acc: 0.8412
#
# Epoch 00050: val_acc did not improve from 0.85410
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001769912.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1608 - acc: 0.9431 - val_loss: 0.5867 - val_acc: 0.8510
#
# Epoch 00051: val_acc did not improve from 0.85410
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001737217.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1558 - acc: 0.9443 - val_loss: 0.5878 - val_acc: 0.8510
#
# Epoch 00052: val_acc did not improve from 0.85410
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001705708.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1538 - acc: 0.9451 - val_loss: 0.5798 - val_acc: 0.8547
#
# Epoch 00053: val_acc improved from 0.85410 to 0.85470, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001675322.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1512 - acc: 0.9448 - val_loss: 0.5887 - val_acc: 0.8507
#
# Epoch 00054: val_acc did not improve from 0.85470
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001646.
# 195/195 [==============================] - 49s 254ms/step - loss: 0.1475 - acc: 0.9472 - val_loss: 0.6049 - val_acc: 0.8466
#
# Epoch 00055: val_acc did not improve from 0.85470
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001617687.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1450 - acc: 0.9473 - val_loss: 0.6199 - val_acc: 0.8503
#
# Epoch 00056: val_acc did not improve from 0.85470
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001590331.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1434 - acc: 0.9484 - val_loss: 0.6180 - val_acc: 0.8491
#
# Epoch 00057: val_acc did not improve from 0.85470
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001563885.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1433 - acc: 0.9486 - val_loss: 0.6328 - val_acc: 0.8448
#
# Epoch 00058: val_acc did not improve from 0.85470
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001538304.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1384 - acc: 0.9505 - val_loss: 0.6284 - val_acc: 0.8498
#
# Epoch 00059: val_acc did not improve from 0.85470
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001513546.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1410 - acc: 0.9490 - val_loss: 0.6134 - val_acc: 0.8532
#
# Epoch 00060: val_acc did not improve from 0.85470
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001489573.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1367 - acc: 0.9509 - val_loss: 0.6083 - val_acc: 0.8533
#
# Epoch 00061: val_acc did not improve from 0.85470
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001466347.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1360 - acc: 0.9512 - val_loss: 0.6237 - val_acc: 0.8496
#
# Epoch 00062: val_acc did not improve from 0.85470
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001443835.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1349 - acc: 0.9522 - val_loss: 0.5968 - val_acc: 0.8560
#
# Epoch 00063: val_acc improved from 0.85470 to 0.85600, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001422003.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1337 - acc: 0.9513 - val_loss: 0.6208 - val_acc: 0.8547
#
# Epoch 00064: val_acc did not improve from 0.85600
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001400822.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1292 - acc: 0.9548 - val_loss: 0.6122 - val_acc: 0.8571
#
# Epoch 00065: val_acc improved from 0.85600 to 0.85710, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001380262.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1267 - acc: 0.9543 - val_loss: 0.6177 - val_acc: 0.8540
#
# Epoch 00066: val_acc did not improve from 0.85710
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001360297.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1288 - acc: 0.9527 - val_loss: 0.6172 - val_acc: 0.8539
#
# Epoch 00067: val_acc did not improve from 0.85710
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001340902.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1305 - acc: 0.9526 - val_loss: 0.6227 - val_acc: 0.8541
#
# Epoch 00068: val_acc did not improve from 0.85710
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001322052.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1250 - acc: 0.9552 - val_loss: 0.6112 - val_acc: 0.8550
#
# Epoch 00069: val_acc did not improve from 0.85710
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001303724.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1238 - acc: 0.9551 - val_loss: 0.6263 - val_acc: 0.8551
#
# Epoch 00070: val_acc did not improve from 0.85710
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.0001285898.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1206 - acc: 0.9566 - val_loss: 0.6192 - val_acc: 0.8549
#
# Epoch 00071: val_acc did not improve from 0.85710
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.0001268553.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1236 - acc: 0.9549 - val_loss: 0.6189 - val_acc: 0.8543
#
# Epoch 00072: val_acc did not improve from 0.85710
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.0001251669.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1214 - acc: 0.9575 - val_loss: 0.6402 - val_acc: 0.8473
#
# Epoch 00073: val_acc did not improve from 0.85710
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.0001235229.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1180 - acc: 0.9570 - val_loss: 0.6206 - val_acc: 0.8556
#
# Epoch 00074: val_acc did not improve from 0.85710
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler setting learning rate to 0.0001219215.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1171 - acc: 0.9576 - val_loss: 0.6187 - val_acc: 0.8566
#
# Epoch 00075: val_acc did not improve from 0.85710
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler setting learning rate to 0.0001203611.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1154 - acc: 0.9581 - val_loss: 0.6253 - val_acc: 0.8565
#
# Epoch 00076: val_acc did not improve from 0.85710
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler setting learning rate to 0.0001188401.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1110 - acc: 0.9598 - val_loss: 0.6434 - val_acc: 0.8546
#
# Epoch 00077: val_acc did not improve from 0.85710
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler setting learning rate to 0.0001173571.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1127 - acc: 0.9595 - val_loss: 0.6365 - val_acc: 0.8536
#
# Epoch 00078: val_acc did not improve from 0.85710
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler setting learning rate to 0.0001159107.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.1138 - acc: 0.9583 - val_loss: 0.6199 - val_acc: 0.8557
#
# Epoch 00079: val_acc did not improve from 0.85710
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler setting learning rate to 0.0001144994.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1106 - acc: 0.9605 - val_loss: 0.6312 - val_acc: 0.8547
#
# Epoch 00080: val_acc did not improve from 0.85710
# Epoch 81/100
#
# Epoch 00081: LearningRateScheduler setting learning rate to 0.0001131222.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1131 - acc: 0.9592 - val_loss: 0.6299 - val_acc: 0.8552
#
# Epoch 00081: val_acc did not improve from 0.85710
# Epoch 82/100
#
# Epoch 00082: LearningRateScheduler setting learning rate to 0.0001117776.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1113 - acc: 0.9596 - val_loss: 0.6805 - val_acc: 0.8482
#
# Epoch 00082: val_acc did not improve from 0.85710
# Epoch 83/100
#
# Epoch 00083: LearningRateScheduler setting learning rate to 0.0001104647.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1073 - acc: 0.9618 - val_loss: 0.6337 - val_acc: 0.8566
#
# Epoch 00083: val_acc did not improve from 0.85710
# Epoch 84/100
#
# Epoch 00084: LearningRateScheduler setting learning rate to 0.0001091822.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1075 - acc: 0.9617 - val_loss: 0.6410 - val_acc: 0.8547
#
# Epoch 00084: val_acc did not improve from 0.85710
# Epoch 85/100
#
# Epoch 00085: LearningRateScheduler setting learning rate to 0.0001079292.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1053 - acc: 0.9615 - val_loss: 0.6290 - val_acc: 0.8598
#
# Epoch 00085: val_acc improved from 0.85710 to 0.85980, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 86/100
#
# Epoch 00086: LearningRateScheduler setting learning rate to 0.0001067046.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1054 - acc: 0.9618 - val_loss: 0.6395 - val_acc: 0.8555
#
# Epoch 00086: val_acc did not improve from 0.85980
# Epoch 87/100
#
# Epoch 00087: LearningRateScheduler setting learning rate to 0.0001055075.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1067 - acc: 0.9611 - val_loss: 0.6568 - val_acc: 0.8572
#
# Epoch 00087: val_acc did not improve from 0.85980
# Epoch 88/100
#
# Epoch 00088: LearningRateScheduler setting learning rate to 0.0001043369.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1023 - acc: 0.9628 - val_loss: 0.6445 - val_acc: 0.8587
#
# Epoch 00088: val_acc did not improve from 0.85980
# Epoch 89/100
#
# Epoch 00089: LearningRateScheduler setting learning rate to 0.0001031921.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1021 - acc: 0.9637 - val_loss: 0.6516 - val_acc: 0.8538
#
# Epoch 00089: val_acc did not improve from 0.85980
# Epoch 90/100
#
# Epoch 00090: LearningRateScheduler setting learning rate to 0.0001020721.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1047 - acc: 0.9621 - val_loss: 0.6505 - val_acc: 0.8568
#
# Epoch 00090: val_acc did not improve from 0.85980
# Epoch 91/100
#
# Epoch 00091: LearningRateScheduler setting learning rate to 0.0001009761.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1015 - acc: 0.9637 - val_loss: 0.6323 - val_acc: 0.8581
#
# Epoch 00091: val_acc did not improve from 0.85980
# Epoch 92/100
#
# Epoch 00092: LearningRateScheduler setting learning rate to 9.99034e-05.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1015 - acc: 0.9634 - val_loss: 0.6477 - val_acc: 0.8583
#
# Epoch 00092: val_acc did not improve from 0.85980
# Epoch 93/100
#
# Epoch 00093: LearningRateScheduler setting learning rate to 9.88533e-05.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1009 - acc: 0.9637 - val_loss: 0.6414 - val_acc: 0.8577
#
# Epoch 00093: val_acc did not improve from 0.85980
# Epoch 94/100
#
# Epoch 00094: LearningRateScheduler setting learning rate to 9.7825e-05.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.1009 - acc: 0.9638 - val_loss: 0.6648 - val_acc: 0.8541
#
# Epoch 00094: val_acc did not improve from 0.85980
# Epoch 95/100
#
# Epoch 00095: LearningRateScheduler setting learning rate to 9.68179e-05.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.0980 - acc: 0.9648 - val_loss: 0.6172 - val_acc: 0.8622
#
# Epoch 00095: val_acc improved from 0.85980 to 0.86220, saving model to Assignment6a//maxAccuracy.hdf5
# Epoch 96/100
#
# Epoch 00096: LearningRateScheduler setting learning rate to 9.58313e-05.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.0966 - acc: 0.9647 - val_loss: 0.6458 - val_acc: 0.8606
#
# Epoch 00096: val_acc did not improve from 0.86220
# Epoch 97/100
#
# Epoch 00097: LearningRateScheduler setting learning rate to 9.48647e-05.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.0962 - acc: 0.9654 - val_loss: 0.6386 - val_acc: 0.8589
#
# Epoch 00097: val_acc did not improve from 0.86220
# Epoch 98/100
#
# Epoch 00098: LearningRateScheduler setting learning rate to 9.39173e-05.
# 195/195 [==============================] - 50s 254ms/step - loss: 0.0970 - acc: 0.9650 - val_loss: 0.6537 - val_acc: 0.8582
#
# Epoch 00098: val_acc did not improve from 0.86220
# Epoch 99/100
#
# Epoch 00099: LearningRateScheduler setting learning rate to 9.29887e-05.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.0918 - acc: 0.9670 - val_loss: 0.6511 - val_acc: 0.8584
#
# Epoch 00099: val_acc did not improve from 0.86220
# Epoch 100/100
#
# Epoch 00100: LearningRateScheduler setting learning rate to 9.20782e-05.
# 195/195 [==============================] - 50s 255ms/step - loss: 0.0945 - acc: 0.9659 - val_loss: 0.6380 - val_acc: 0.8610
#
# Epoch 00100: val_acc did not improve from 0.86220
# Model took 5005.67 seconds to train
# Accuracy on test data is: 86.10
